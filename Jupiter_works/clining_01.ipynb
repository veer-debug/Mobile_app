# %%
import pandas as pd
import numpy as np

# %%
df=pd.read_csv('./Datasets/Smart_Phone.csv')

# %%
df.head()
# Out:
#                         Name    Price  Rating  \
# 0       OnePlus Nord CE 4 5G  ₹24,999    4.20
# 1    Motorola Edge 50 Pro 5G  ₹31,999    4.70
# 2          OnePlus Nord 4 5G  ₹32,999    4.35
# 3                 Vivo T3 5G  ₹19,999    4.70
# 4  OnePlus Nord CE 4 Lite 5G  ₹20,990    4.70
#
#                                              Network  \
# 0                 Dual Sim, 3G, 4G, 5G, VoLTE, Wi-Fi
# 1      Dual Sim, 3G, 4G, 5G, VoLTE, Vo5G, Wi-Fi, NFC
# 2  Dual Sim, 3G, 4G, 5G, VoLTE, Wi-Fi, NFC, IR Bl...
# 3                 Dual Sim, 3G, 4G, 5G, VoLTE, Wi-Fi
# 4                 Dual Sim, 3G, 4G, 5G, VoLTE, Wi-Fi
#
#                                           Processor                   Storage  \
# 0  Snapdragon 7 Gen3, Octa Core, 2.63 GHz Processor  8 GB RAM, 128 GB inbuilt
# 1  Snapdragon 7 Gen3, Octa Core, 2.63 GHz Processor  8 GB RAM, 256 GB inbuilt
# 2  Snapdragon 7+ Gen3, Octa Core, 2.8 GHz Processor  8 GB RAM, 128 GB inbuilt
# ...

# %%
df.isna().sum()
# Out:
# Name          0
# Price         0
# Rating        0
# Network       0
# Processor     0
# Storage       0
# Battery       0
# Display       0
# Camera        0
# Memory        0
# OS            0
# Image Link    0
# dtype: int64

# %%
# Name	Price	Rating	Network	Processor	Storage	Battery	Display	Camera	Memory	OS	Image Link

# %%
df['Name'][0]
# Out:
# 'OnePlus Nord CE 4 5G'

# %%
df.insert(0,'Brand',df['Name'].str.split(' ').str.get(0))

# %%
df.sample(2)
# Out:
#        Brand                                     Name    Price  Rating  \
# 860  Samsung  Samsung Galaxy S21 5G (8GB RAM + 256GB)  ₹73,999    4.00
# 470    Nubia                    Nubia Redmagic 8s Pro  ₹45,990    4.05
#
#                                      Network  \
# 860  Dual Sim, 3G, 4G, 5G, VoLTE, Wi-Fi, NFC
# 470  Dual Sim, 3G, 4G, 5G, VoLTE, Wi-Fi, NFC
#
#                                              Processor  \
# 860         Exynos  2100, Octa Core, 2.9 GHz Processor
# 470  Snapdragon 8+ Gen2, Octa Core, 3.36 GHz Processor
#
#                       Storage                                   Battery  \
# 860  8 GB RAM, 256 GB inbuilt   4000 mAh Battery with 25W Fast Charging
# 470  8 GB RAM, 128 GB inbuilt  6000 mAh Battery with 165W Fast Charging
#
#                                                Display  \
# 860  6.2 inches, 1080 x 2400 px, 120 Hz Display wit...
# 470         6.8 inches, 1116 x 2480 px, 120 Hz Display
#
# ...

# %%
# Price

# %%
df['Price'].value_counts()
# Out:
# Price
# ₹29,990    27
# ₹24,999    19
# ₹22,999    18
# ₹24,990    17
# ₹19,999    16
#            ..
# ₹22,500     1
# ₹11,488     1
# ₹21,480     1
# ₹22,499     1
# ₹17,290     1
# Name: count, Length: 389, dtype: int64

# %%
df['Price']=df['Price'].str.split('₹').str.get(1).str.replace(',','').str.strip().astype('float64')

# %%
df['Rating']=df['Rating'].astype('float64')

# %%
df['Network'].value_counts()
# Out:
# Network
# Dual Sim, 3G, 4G, 5G, VoLTE, Wi-Fi, NFC                      302
# Dual Sim, 3G, 4G, 5G, VoLTE, Wi-Fi                           213
# Dual Sim, 3G, 4G, 5G, VoLTE, Wi-Fi, NFC, IR Blaster          119
# Dual Sim, 3G, 4G, VoLTE, Wi-Fi                               101
# Dual Sim, 3G, 4G, 5G, VoLTE, Wi-Fi, IR Blaster                68
# Dual Sim, 3G, 4G, VoLTE, Wi-Fi, NFC                           44
# Dual Sim, 3G, 4G, 5G, VoLTE, Vo5G, Wi-Fi, NFC                 40
# Dual Sim, 3G, 4G, 5G, VoLTE, Vo5G, Wi-Fi, NFC, IR Blaster     26
# Dual Sim, 3G, 4G, VoLTE, Wi-Fi, IR Blaster                    23
# Dual Sim, 3G, 4G, VoLTE, Wi-Fi, NFC, IR Blaster               13
# Single Sim, 3G, 4G, 5G, VoLTE, Wi-Fi, NFC                      8
# Dual Sim, 3G, 4G, 5G, VoLTE, Vo5G, Wi-Fi                       5
# Dual Sim, 3G, 4G, 5G, VoLTE, Vo5G, Wi-Fi, IR Blaster           3
# Dual Sim, 3G, 4G, Wi-Fi, NFC                                   3
# ...

# %%
def is5G(text):
    if '5G' in text:
        return 1
    return 0

# %%
temp=df['Network'].apply(is5G)

# %%
df.insert(3,'5G',temp)

# %%
df.head(2)
# Out:
#       Brand                     Name    Price  5G  Rating  \
# 0   OnePlus     OnePlus Nord CE 4 5G  24999.0   1     4.2
# 1  Motorola  Motorola Edge 50 Pro 5G  31999.0   1     4.7
#
#                                          Network  \
# 0             Dual Sim, 3G, 4G, 5G, VoLTE, Wi-Fi
# 1  Dual Sim, 3G, 4G, 5G, VoLTE, Vo5G, Wi-Fi, NFC
#
#                                           Processor                   Storage  \
# 0  Snapdragon 7 Gen3, Octa Core, 2.63 GHz Processor  8 GB RAM, 128 GB inbuilt
# 1  Snapdragon 7 Gen3, Octa Core, 2.63 GHz Processor  8 GB RAM, 256 GB inbuilt
#
#                                     Battery  \
# 0  5500 mAh Battery with 100W Fast Charging
# 1   4500 mAh Battery with 68W Fast Charging
#
#                                              Display  \
# 0  6.7 inches, 1080 x 2412 px, 120 Hz Display wit...
# 1  6.7 inches, 1220 x 2712 px, 144 Hz Display wit...
#
#                                               Camera  \
# ...

# %%
def isNFC(text):
    if 'NFC' in text:
        return 1
    return 0

# %%
temp=df['Network'].apply(isNFC)

# %%
df.insert(4,'NFC',temp)

# %%
df.sample(2)
# Out:
#         Brand                            Name    Price  5G  NFC  Rating  \
# 738  Motorola  Motorola Moto G Stylus 5G 2024  39990.0   1    1    4.75
# 236    Xiaomi                   Xiaomi 14 Pro  56990.0   1    1    4.00
#
#                                                Network  \
# 738          Single Sim, 3G, 4G, 5G, VoLTE, Wi-Fi, NFC
# 236  Dual Sim, 3G, 4G, 5G, VoLTE, Wi-Fi, NFC, IR Bl...
#
#                                            Processor  \
# 738         Snapdragon, Octa Core, 2.2 GHz Processor
# 236  Snapdragon 8 Gen3, Octa Core, 3.3 GHz Processor
#
#                        Storage                                   Battery  \
# 738   6 GB RAM, 128 GB inbuilt       5000 mAh Battery with Fast Charging
# 236  12 GB RAM, 256 GB inbuilt  4880 mAh Battery with 120W Fast Charging
#
#                                                Display  \
# 738  6.5 inches, 1080 x 2200 px, 120 Hz Display wit...
# 236  6.73 inches, 1440 x 3200 px, 120 Hz Display wi...
#
# ...

# %%
def isIRBlaster(text):
    if 'IR Blaster' in text:
        return 1
    return 0

# %%
temp=df['Network'].apply(isIRBlaster)

# %%
df.insert(5,'IrBlaster',temp)

# %%
df.head(2)
# Out:
#       Brand                     Name    Price  5G  NFC  IrBlaster  Rating  \
# 0   OnePlus     OnePlus Nord CE 4 5G  24999.0   1    0          0     4.2
# 1  Motorola  Motorola Edge 50 Pro 5G  31999.0   1    1          0     4.7
#
#                                          Network  \
# 0             Dual Sim, 3G, 4G, 5G, VoLTE, Wi-Fi
# 1  Dual Sim, 3G, 4G, 5G, VoLTE, Vo5G, Wi-Fi, NFC
#
#                                           Processor                   Storage  \
# 0  Snapdragon 7 Gen3, Octa Core, 2.63 GHz Processor  8 GB RAM, 128 GB inbuilt
# 1  Snapdragon 7 Gen3, Octa Core, 2.63 GHz Processor  8 GB RAM, 256 GB inbuilt
#
#                                     Battery  \
# 0  5500 mAh Battery with 100W Fast Charging
# 1   4500 mAh Battery with 68W Fast Charging
#
#                                              Display  \
# 0  6.7 inches, 1080 x 2412 px, 120 Hz Display wit...
# 1  6.7 inches, 1220 x 2712 px, 144 Hz Display wit...
#
# ...

# %%
df.drop(columns=['Network'],inplace=True)

# %%
df.head(3)
# Out:
#       Brand                     Name    Price  5G  NFC  IrBlaster  Rating  \
# 0   OnePlus     OnePlus Nord CE 4 5G  24999.0   1    0          0    4.20
# 1  Motorola  Motorola Edge 50 Pro 5G  31999.0   1    1          0    4.70
# 2   OnePlus        OnePlus Nord 4 5G  32999.0   1    1          1    4.35
#
#                                           Processor                   Storage  \
# 0  Snapdragon 7 Gen3, Octa Core, 2.63 GHz Processor  8 GB RAM, 128 GB inbuilt
# 1  Snapdragon 7 Gen3, Octa Core, 2.63 GHz Processor  8 GB RAM, 256 GB inbuilt
# 2  Snapdragon 7+ Gen3, Octa Core, 2.8 GHz Processor  8 GB RAM, 128 GB inbuilt
#
#                                     Battery  \
# 0  5500 mAh Battery with 100W Fast Charging
# 1   4500 mAh Battery with 68W Fast Charging
# 2  5000 mAh Battery with 120W Fast Charging
#
#                                              Display  \
# 0  6.7 inches, 1080 x 2412 px, 120 Hz Display wit...
# 1  6.7 inches, 1220 x 2712 px, 144 Hz Display wit...
# ...

# %%
# Processor
df['Processor'].value_counts()
# Out:
# Processor
# Snapdragon 8 Gen3, Octa Core, 3.3 GHz Processor     48
# Snapdragon 8 Gen2, Octa Core, 3.2 GHz Processor     43
# Snapdragon 695, Octa Core, 2.2 GHz Processor        30
# Snapdragon 8+ Gen1, Octa Core, 3.2 GHz Processor    28
# Dimensity 7050, Octa Core, 2.6 GHz Processor        27
#                                                     ..
# Dimensity 8300, Octa Core, 3.35 GHz Processor        1
# Google Tensor G2, Octa Core, 2.85 GHz Processor      1
# Snapdragon 480+, Octa Core, 2.2 GHz Processor        1
# Snapdragon 8 gen2, Octa Core, 3.2 GHz Processor      1
# Helio P60, Octa Core, 1.99 GHz Processor             1
# Name: count, Length: 240, dtype: int64

# %%
# Processor Brand
df.insert(6,'Processor_brand',df['Processor'].str.split().str.get(0).str.strip())

# %%
df.head(1)
# Out:
#      Brand                  Name    Price  5G  NFC  IrBlaster Processor_brand  \
# 0  OnePlus  OnePlus Nord CE 4 5G  24999.0   1    0          0      Snapdragon
#
#    Rating                                         Processor  \
# 0     4.2  Snapdragon 7 Gen3, Octa Core, 2.63 GHz Processor
#
#                     Storage                                   Battery  \
# 0  8 GB RAM, 128 GB inbuilt  5500 mAh Battery with 100W Fast Charging
#
#                                              Display  \
# 0  6.7 inches, 1080 x 2412 px, 120 Hz Display wit...
#
#                                         Camera  \
# 0  50 MP + 8 MP Dual Rear & 16 MP Front Camera
#
#                             Memory           OS  \
# 0  Memory Card (Hybrid), upto 1 TB  Android v14
#
#                                           Image Link
# 0  https://cdn1.smartprix.com/rx-iJIRhERgV-w280-h...

# %%
# Processor_genaration
df['Processor'].str.split().str.get(1)
# Out:
# 0          7
# 1          7
# 2         7+
# 3      7200,
# 4          7
#        ...
# 975    9611,
# 976     P60,
# 977      865
# 978      662
# 979     990,
# Name: Processor, Length: 980, dtype: object

# %%
df.insert(7,"Processor_gen",df['Processor'].str.split(',').str.get(0).str.strip().str.split(' ',n=1 ).str.get(1).str.strip())

# %%
df.sample(2)
# Out:
#        Brand               Name    Price  5G  NFC  IrBlaster Processor_brand  \
# 30   OnePlus  OnePlus Nord 3 5G  25188.0   1    1          1       Dimensity
# 499   Xiaomi      Xiaomi 15 Pro  69990.0   1    1          1      Snapdragon
#
#     Processor_gen  Rating                                      Processor  \
# 30           9000    4.15  Dimensity 9000, Octa Core, 3.05 GHz Processor
# 499        8 Gen4    4.05         Snapdragon 8 Gen4, Octa Core Processor
#
#                        Storage                                   Battery  \
# 30    8 GB RAM, 128 GB inbuilt   5000 mAh Battery with 80W Fast Charging
# 499  12 GB RAM, 256 GB inbuilt  4820 mAh Battery with 200W Fast Charging
#
#                                                Display  \
# 30   6.74 inches, 1240 x 2772 px, 120 Hz Display wi...
# 499  6.78 inches, 1440 x 3200 px, 165 Hz Display wi...
#
#                                                 Camera  \
# 30   50 MP + 8 MP + 2 MP Triple Rear & 16 MP Front ...
# ...

# %%
# Number of cores
def cores(text):
    if 'Octa' in text:
        return 8
    elif 'Deca' in text:
        return 10
    else:
        return 4

# %%
temp=df['Processor'].apply(cores)

# %%
df.insert(8,"Cores",temp)

# %%
# Processor_Speed

df.head(4)
# Out:
#       Brand                     Name    Price  5G  NFC  IrBlaster  \
# 0   OnePlus     OnePlus Nord CE 4 5G  24999.0   1    0          0
# 1  Motorola  Motorola Edge 50 Pro 5G  31999.0   1    1          0
# 2   OnePlus        OnePlus Nord 4 5G  32999.0   1    1          1
# 3      Vivo               Vivo T3 5G  19999.0   1    0          0
#
#   Processor_brand Processor_gen  Cores  Rating  \
# 0      Snapdragon        7 Gen3      8    4.20
# 1      Snapdragon        7 Gen3      8    4.70
# 2      Snapdragon       7+ Gen3      8    4.35
# 3       Dimensity          7200      8    4.70
#
#                                           Processor                   Storage  \
# 0  Snapdragon 7 Gen3, Octa Core, 2.63 GHz Processor  8 GB RAM, 128 GB inbuilt
# 1  Snapdragon 7 Gen3, Octa Core, 2.63 GHz Processor  8 GB RAM, 256 GB inbuilt
# 2  Snapdragon 7+ Gen3, Octa Core, 2.8 GHz Processor  8 GB RAM, 128 GB inbuilt
# 3      Dimensity 7200, Octa Core, 2.8 GHz Processor  8 GB RAM, 128 GB inbuilt
#
# ...

# %%
speed=df['Processor'].str.split().str.get(-3).str.strip()

# %%
df.insert(8,"Processor_speed",speed)

# %%
df.drop(columns=['Processor'],inplace=True)

# %%
df.head(2)
# Out:
#       Brand                     Name    Price  5G  NFC  IrBlaster  \
# 0   OnePlus     OnePlus Nord CE 4 5G  24999.0   1    0          0
# 1  Motorola  Motorola Edge 50 Pro 5G  31999.0   1    1          0
#
#   Processor_brand Processor_gen Processor_speed  Cores  Rating  \
# 0      Snapdragon        7 Gen3            2.63      8     4.2
# 1      Snapdragon        7 Gen3            2.63      8     4.7
#
#                     Storage                                   Battery  \
# 0  8 GB RAM, 128 GB inbuilt  5500 mAh Battery with 100W Fast Charging
# 1  8 GB RAM, 256 GB inbuilt   4500 mAh Battery with 68W Fast Charging
#
#                                              Display  \
# 0  6.7 inches, 1080 x 2412 px, 120 Hz Display wit...
# 1  6.7 inches, 1220 x 2712 px, 144 Hz Display wit...
#
#                                               Camera  \
# 0        50 MP + 8 MP Dual Rear & 16 MP Front Camera
# 1  50 MP + 13 MP + 10 MP Triple Rear & 50 MP Fron...
#
# ...

# %%
# Storage
df['Storage'].value_counts()
# Out:
# Storage
# 8 GB RAM, 128 GB inbuilt     321
# 8 GB RAM, 256 GB inbuilt     193
# 12 GB RAM, 256 GB inbuilt    183
# 6 GB RAM, 128 GB inbuilt     171
# 12 GB RAM, 512 GB inbuilt     33
# 6 GB RAM, 64 GB inbuilt       21
# 16 GB RAM, 256 GB inbuilt     20
# 16 GB RAM, 512 GB inbuilt      9
# 12 GB RAM, 128 GB inbuilt      8
# 6 GB RAM, 256 GB inbuilt       4
# 8 GB RAM, 512 GB inbuilt       4
# 18 GB RAM, 512 GB inbuilt      3
# 6 GB RAM, 512 GB inbuilt       3
# 12 GB RAM, 1 TB inbuilt        2
# 24 GB RAM, 1 TB inbuilt        2
# 6 GB RAM, 1 TB inbuilt         1
# 16 GB RAM, 1 TB inbuilt        1
# 8 GB RAM, 1 TB inbuilt         1
# Name: count, dtype: int64

# %%
ram=df['Storage'].str.split().str.get(0)

# %%
df.insert(9,"Ram",ram)

# %%
df['Storage']=df['Storage'].str.split().str.get(-3).astype('Int64')

# %%
df.head(3)
# Out:
#       Brand                     Name    Price  5G  NFC  IrBlaster  \
# 0   OnePlus     OnePlus Nord CE 4 5G  24999.0   1    0          0
# 1  Motorola  Motorola Edge 50 Pro 5G  31999.0   1    1          0
# 2   OnePlus        OnePlus Nord 4 5G  32999.0   1    1          1
#
#   Processor_brand Processor_gen Processor_speed Ram  Cores  Rating  Storage  \
# 0      Snapdragon        7 Gen3            2.63   8      8    4.20      128
# 1      Snapdragon        7 Gen3            2.63   8      8    4.70      256
# 2      Snapdragon       7+ Gen3             2.8   8      8    4.35      128
#
#                                     Battery  \
# 0  5500 mAh Battery with 100W Fast Charging
# 1   4500 mAh Battery with 68W Fast Charging
# 2  5000 mAh Battery with 120W Fast Charging
#
#                                              Display  \
# 0  6.7 inches, 1080 x 2412 px, 120 Hz Display wit...
# 1  6.7 inches, 1220 x 2712 px, 144 Hz Display wit...
# ...

# %%
df['Battery'].value_counts()
# Out:
# Battery
# 5000 mAh Battery with 33W Fast Charging     92
# 5000 mAh Battery with 67W Fast Charging     63
# 5000 mAh Battery with 18W Fast Charging     55
# 5000 mAh Battery with 80W Fast Charging     43
# 5000 mAh Battery with 25W Fast Charging     40
#                                             ..
# 5200 mAh Battery with 210W Fast Charging     1
# 4800 mAh Battery with 150W Fast Charging     1
# 6000 mAh Battery with 165W Fast Charging     1
# 4870 mAh Battery with 120W Fast Charging     1
# 4000 mAh Battery with 21W Fast Charging      1
# Name: count, Length: 232, dtype: int64

# %%
df.insert(13,"BattryMAH",df['Battery'].str.split('mAh').str.get(0).str.strip())

# %%
df.head(3)
# Out:
#       Brand                     Name    Price  5G  NFC  IrBlaster  \
# 0   OnePlus     OnePlus Nord CE 4 5G  24999.0   1    0          0
# 1  Motorola  Motorola Edge 50 Pro 5G  31999.0   1    1          0
# 2   OnePlus        OnePlus Nord 4 5G  32999.0   1    1          1
#
#   Processor_brand Processor_gen Processor_speed Ram  Cores  Rating  Storage  \
# 0      Snapdragon        7 Gen3            2.63   8      8    4.20      128
# 1      Snapdragon        7 Gen3            2.63   8      8    4.70      256
# 2      Snapdragon       7+ Gen3             2.8   8      8    4.35      128
#
#   BattryMAH                                   Battery  \
# 0      5500  5500 mAh Battery with 100W Fast Charging
# 1      4500   4500 mAh Battery with 68W Fast Charging
# 2      5000  5000 mAh Battery with 120W Fast Charging
#
#                                              Display  \
# 0  6.7 inches, 1080 x 2412 px, 120 Hz Display wit...
# 1  6.7 inches, 1220 x 2712 px, 144 Hz Display wit...
# ...

# %%
# Fast Charging
def isFASTcHARGING(text):
    if 'Fast Charging' in text:
        return 1
    return 0

# %%
fast=df['Battery'].apply(isFASTcHARGING)

# %%
df.insert(14,'FastCharging',fast)

# %%
df.head(3)
# Out:
#       Brand                     Name    Price  5G  NFC  IrBlaster  \
# 0   OnePlus     OnePlus Nord CE 4 5G  24999.0   1    0          0
# 1  Motorola  Motorola Edge 50 Pro 5G  31999.0   1    1          0
# 2   OnePlus        OnePlus Nord 4 5G  32999.0   1    1          1
#
#   Processor_brand Processor_gen Processor_speed Ram  ...  Rating  Storage  \
# 0      Snapdragon        7 Gen3            2.63   8  ...    4.20      128
# 1      Snapdragon        7 Gen3            2.63   8  ...    4.70      256
# 2      Snapdragon       7+ Gen3             2.8   8  ...    4.35      128
#
#    BattryMAH FastCharging                                   Battery  \
# 0       5500            1  5500 mAh Battery with 100W Fast Charging
# 1       4500            1   4500 mAh Battery with 68W Fast Charging
# 2       5000            1  5000 mAh Battery with 120W Fast Charging
#
#                                              Display  \
# 0  6.7 inches, 1080 x 2412 px, 120 Hz Display wit...
# ...

# %%
df.drop(columns=['Battery'],inplace=True)

# %%
df.head(3)
# Out:
#       Brand                     Name    Price  5G  NFC  IrBlaster  \
# 0   OnePlus     OnePlus Nord CE 4 5G  24999.0   1    0          0
# 1  Motorola  Motorola Edge 50 Pro 5G  31999.0   1    1          0
# 2   OnePlus        OnePlus Nord 4 5G  32999.0   1    1          1
#
#   Processor_brand Processor_gen Processor_speed Ram  Cores  Rating  Storage  \
# 0      Snapdragon        7 Gen3            2.63   8      8    4.20      128
# 1      Snapdragon        7 Gen3            2.63   8      8    4.70      256
# 2      Snapdragon       7+ Gen3             2.8   8      8    4.35      128
#
#   BattryMAH  FastCharging                                            Display  \
# 0      5500             1  6.7 inches, 1080 x 2412 px, 120 Hz Display wit...
# 1      4500             1  6.7 inches, 1220 x 2712 px, 144 Hz Display wit...
# 2      5000             1  6.78 inches, 1240 x 2772 px, 120 Hz Display wi...
#
#                                               Camera  \
# ...

# %%
# OS

t=df[df['OS']=='No FM Radio']

# %%
t.head(2)
# Out:
#       Brand                     Name    Price  5G  NFC  IrBlaster  \
# 1  Motorola  Motorola Edge 50 Pro 5G  31999.0   1    1          0
# 2   OnePlus        OnePlus Nord 4 5G  32999.0   1    1          1
#
#   Processor_brand Processor_gen Processor_speed Ram  Cores  Rating  Storage  \
# 1      Snapdragon        7 Gen3            2.63   8      8    4.70      256
# 2      Snapdragon       7+ Gen3             2.8   8      8    4.35      128
#
#   BattryMAH  FastCharging                                            Display  \
# 1      4500             1  6.7 inches, 1220 x 2712 px, 144 Hz Display wit...
# 2      5000             1  6.78 inches, 1240 x 2772 px, 120 Hz Display wi...
#
#                                               Camera       Memory  \
# 1  50 MP + 13 MP + 10 MP Triple Rear & 50 MP Fron...  Android v14
# 2  50 MP + 13 MP + 5 MP Triple Rear & 32 MP Front...  Android v14
#
#             OS                                         Image Link
# ...

# %%
t['OS']=t['Memory']
# Out:
# C:\Users\Ranveer\AppData\Local\Temp\ipykernel_14648\3167424152.py:1: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   t['OS']=t['Memory']

# %%
df.loc[df['OS'] == 'No FM Radio', 'OS'] = t['OS']

# %%
df['OS'].value_counts()
# Out:
# OS
# Android v13                  323
# Android v14                  224
# Android v12                  162
# Android v11                  109
# Bluetooth                     38
# Android v10                   23
# Memory Card Not Supported     21
# Android v15                   20
# iOS v17                       14
# Android v10.0                  8
# Android v9.0 (Pie)             5
# iOS v18                        5
# iOS v16                        4
# Flyme 10                       3
# EMUI v14                       2
# Hongmeng OS v4.0               2
# iOS v14.0                      2
# HarmonyOS v4                   2
# iOS v15                        2
# iOS v19                        1
# Android v12.1                  1
# HarmonyOS v3.0                 1
# Hongmeng OS v5.0               1
# Android v8.1 (Oreo)            1
# iOS v20                        1
# Android v8.0 (Oreo)            1
# HarmonyOS v4.0                 1
# EMUI v13                       1
# ...

# %%
# OS distrubutar
df.insert(18,'OSType',df['OS'].str.split().str.get(0).str.strip())

# %%
df.head(2)
# Out:
#       Brand                     Name    Price  5G  NFC  IrBlaster  \
# 0   OnePlus     OnePlus Nord CE 4 5G  24999.0   1    0          0
# 1  Motorola  Motorola Edge 50 Pro 5G  31999.0   1    1          0
#
#   Processor_brand Processor_gen Processor_speed Ram  ...  Rating  Storage  \
# 0      Snapdragon        7 Gen3            2.63   8  ...     4.2      128
# 1      Snapdragon        7 Gen3            2.63   8  ...     4.7      256
#
#    BattryMAH FastCharging                                            Display  \
# 0       5500            1  6.7 inches, 1080 x 2412 px, 120 Hz Display wit...
# 1       4500            1  6.7 inches, 1220 x 2712 px, 144 Hz Display wit...
#
#                                               Camera  \
# 0        50 MP + 8 MP Dual Rear & 16 MP Front Camera
# 1  50 MP + 13 MP + 10 MP Triple Rear & 50 MP Fron...
#
#                             Memory   OSType           OS  \
# 0  Memory Card (Hybrid), upto 1 TB  Android  Android v14
# ...

# %%
# OS Version
df.insert(19,'OS_Version',df['OS'].str.split().str.get(1).str.strip().str.split('v').str.get(-1).str.strip())

# %%
df.head()
df.drop(columns=['OS'],inplace=True)

# %%
df[df['OS_Version']=='OS']
# Out:
#       Brand                     Name    Price  5G  NFC  IrBlaster  \
# 706  Huawei       Huawei Mate 60 Pro  79990.0   1    1          1
# 735  Huawei       Huawei Mate 70 Pro  84990.0   1    1          1
# 891  Huawei  Huawei Mate 60 Pro Plus  98990.0   1    1          1
#
#     Processor_brand   Processor_gen Processor_speed Ram  ...  Rating  Storage  \
# 706           Kirin           9000S            2.62  12  ...    4.15      256
# 735            Octa  Core Processor            Octa  12  ...    4.05      256
# 891           Kirin           9000S            2.62  16  ...    4.65      512
#
#      BattryMAH FastCharging  \
# 706       5000            1
# 735       5000            1
# 891       5000            1
#
#                                                Display  \
# 706  6.82 inches, 1212 x 2616 px, 120 Hz Display wi...
# 735  6.8 inches, 1212 x 2616 px, 144 Hz Display wit...
# 891  6.82 inches, 1260 x 2720 px, 120 Hz Display wi...
#
# ...

# %%
df.loc[df['OS_Version'] == 'OS','OS_Version'] = pd.Series(['HiSilicon','HiSilicon','HiSilicon'])

# %%
df['OS_Version'].value_counts()
# Out:
# OS_Version
# 13      324
# 14      226
# 12      162
# 11      109
# 10       26
# 15       22
# Card     21
# 17       14
# 10.0      8
# 18        5
# 9.0       5
# 16        4
# 4         2
# 14.0      2
# 20        1
# 12.1      1
# 19        1
# 3.0       1
# 8.1       1
# 8.0       1
# 4.0       1
# 2.0       1
# Name: count, dtype: int64

# %%
t=df[df['OS_Version']=='Card']

# %%
# t['OSType']=pd.Series(['Android']*21)

# %%
# df.iloc[df['OS_Version']=='Card','OSType']

# %%
df.loc[df['OS_Version'] == 'Card', 'OSType'] = 'Android'

# %%
df['OSType'].value_counts()
# Out:
# OSType
# Android      898
# Bluetooth     38
# iOS           29
# HarmonyOS      5
# Flyme          3
# Hongmeng       3
# EMUI           3
# Harmony        1
# Name: count, dtype: int64

# %%
def os(text):
    if text=='HarmonyOS':
        return 'Harmony'
    else:
        return text

# %%
df['OSType']=df['OSType'].apply(os)

# %%
df['OSType'].value_counts()
# Out:
# OSType
# Android      898
# Bluetooth     38
# iOS           29
# Harmony        6
# Flyme          3
# Hongmeng       3
# EMUI           3
# Name: count, dtype: int64

# %%
df.loc[df['OSType'] == 'Bluetooth', 'OSType']
# Out:
# 49     Bluetooth
# 52     Bluetooth
# 83     Bluetooth
# 175    Bluetooth
# 197    Bluetooth
# 214    Bluetooth
# 215    Bluetooth
# 256    Bluetooth
# 291    Bluetooth
# 295    Bluetooth
# 330    Bluetooth
# 355    Bluetooth
# 356    Bluetooth
# 358    Bluetooth
# 392    Bluetooth
# 394    Bluetooth
# 405    Bluetooth
# 420    Bluetooth
# 434    Bluetooth
# 458    Bluetooth
# 471    Bluetooth
# 485    Bluetooth
# 582    Bluetooth
# 591    Bluetooth
# 607    Bluetooth
# 609    Bluetooth
# 622    Bluetooth
# 630    Bluetooth
# 648    Bluetooth
# 708    Bluetooth
# 713    Bluetooth
# 762    Bluetooth
# 792    Bluetooth
# 799    Bluetooth
# 835    Bluetooth
# 892    Bluetooth
# 918    Bluetooth
# 965    Bluetooth
# Name: OSType, dtype: object

# %%
df.loc[df['OSType'] == 'Bluetooth', 'OSType']=df.loc[df['OSType'] == 'Bluetooth', 'Memory'].str.split().str.get(0).str.strip()

# %%
df['OSType'].value_counts()
# Out:
# OSType
# Android     936
# iOS          29
# Harmony       6
# Flyme         3
# Hongmeng      3
# EMUI          3
# Name: count, dtype: int64

# %%
df['OS_Version'].value_counts()
# Out:
# OS_Version
# 13      324
# 14      226
# 12      162
# 11      109
# 10       26
# 15       22
# Card     21
# 17       14
# 10.0      8
# 18        5
# 9.0       5
# 16        4
# 4         2
# 14.0      2
# 20        1
# 12.1      1
# 19        1
# 3.0       1
# 8.1       1
# 8.0       1
# 4.0       1
# 2.0       1
# Name: count, dtype: int64

# %%
t = df[(df['OSType'] == 'Android') & (df['OS_Version'] != 'Card')].sample(21,random_state=60)['OS_Version']

# %%
t
# Out:
# 697     14
# 960     11
# 43      13
# 935     12
# 802     13
# 432     15
# 285     13
# 341     13
# 566     11
# 569     11
# 592     11
# 639     14
# 715     12
# 299     12
# 708    NaN
# 365     14
# 196     14
# 839     12
# 371     11
# 924     12
# 976     10
# Name: OS_Version, dtype: object

# %%
df.loc[df['OS_Version'] == 'Card','OS_Version']=t

# %%
df['OS_Version'].value_counts()
# Out:
# OS_Version
# 13      324
# 14      226
# 12      162
# 11      109
# 10       26
# 15       22
# 17       14
# 10.0      8
# 18        5
# 9.0       5
# 16        4
# 4         2
# 14.0      2
# 20        1
# 12.1      1
# 19        1
# 3.0       1
# 8.1       1
# 8.0       1
# 4.0       1
# 2.0       1
# Name: count, dtype: int64

# %%
df['OS_Version'] = pd.to_numeric(df['OS_Version'], errors='coerce')

# %%
df.loc[df['OS_Version'].isna(), 'OS_Version'] = df['OS_Version'].median()

# %%
df[df['OS_Version'].isna()]
# Out:
# Empty DataFrame
# Columns: [Brand, Name, Price, 5G, NFC, IrBlaster, Processor_brand, Processor_gen, Processor_speed, Ram, Cores, Rating, Storage, BattryMAH, FastCharging, Display, Camera, Memory, OSType, OS_Version, Image Link]
# Index: []
#
# [0 rows x 21 columns]

# %%
df.head(2)
# Out:
#       Brand                     Name    Price  5G  NFC  IrBlaster  \
# 0   OnePlus     OnePlus Nord CE 4 5G  24999.0   1    0          0
# 1  Motorola  Motorola Edge 50 Pro 5G  31999.0   1    1          0
#
#   Processor_brand Processor_gen Processor_speed Ram  ...  Rating  Storage  \
# 0      Snapdragon        7 Gen3            2.63   8  ...     4.2      128
# 1      Snapdragon        7 Gen3            2.63   8  ...     4.7      256
#
#    BattryMAH FastCharging                                            Display  \
# 0       5500            1  6.7 inches, 1080 x 2412 px, 120 Hz Display wit...
# 1       4500            1  6.7 inches, 1220 x 2712 px, 144 Hz Display wit...
#
#                                               Camera  \
# 0        50 MP + 8 MP Dual Rear & 16 MP Front Camera
# 1  50 MP + 13 MP + 10 MP Triple Rear & 50 MP Fron...
#
#                             Memory   OSType OS_Version  \
# 0  Memory Card (Hybrid), upto 1 TB  Android       14.0
# ...

# %%
# Display
df['Display'].value_counts()
# Out:
# Display
# 6.67 inches, 1080 x 2400 px, 120 Hz Display with Punch Hole    78
# 6.7 inches, 1080 x 2412 px, 120 Hz Display with Punch Hole     47
# 6.78 inches, 1080 x 2400 px, 120 Hz Display with Punch Hole    26
# 6.78 inches, 1260 x 2800 px, 120 Hz Display with Punch Hole    19
# 6.43 inches, 1080 x 2400 px, 90 Hz Display with Punch Hole     19
#                                                                ..
# 6.81 inches, 1440 x 3200 px, 120 Hz Display with Punch Hole     1
# 5 inches, 1080 x 2400 px, 120 Hz Display with Punch Hole        1
# 6.8 inches, 1080 x 2412 px, 90 Hz Display with Punch Hole       1
# 8.2 inches, 1914 x 2160 px, 144 Hz Display                      1
# 6.9 inches, 1440 x 3088 px, 120 Hz Display with Punch Hole      1
# Name: count, Length: 365, dtype: int64

# %%
df.insert(15,"DisplayHW",df['Display'].str.split().str.get(0).str.strip())

# %%
df.head(2)
# Out:
#       Brand                     Name    Price  5G  NFC  IrBlaster  \
# 0   OnePlus     OnePlus Nord CE 4 5G  24999.0   1    0          0
# 1  Motorola  Motorola Edge 50 Pro 5G  31999.0   1    1          0
#
#   Processor_brand Processor_gen Processor_speed Ram  ...  Storage  BattryMAH  \
# 0      Snapdragon        7 Gen3            2.63   8  ...      128       5500
# 1      Snapdragon        7 Gen3            2.63   8  ...      256       4500
#
#    FastCharging DisplayHW                                            Display  \
# 0             1       6.7  6.7 inches, 1080 x 2412 px, 120 Hz Display wit...
# 1             1       6.7  6.7 inches, 1220 x 2712 px, 144 Hz Display wit...
#
#                                               Camera  \
# 0        50 MP + 8 MP Dual Rear & 16 MP Front Camera
# 1  50 MP + 13 MP + 10 MP Triple Rear & 50 MP Fron...
#
#                             Memory   OSType OS_Version  \
# 0  Memory Card (Hybrid), upto 1 TB  Android       14.0
# ...

# %%
df.insert(16,'resulution_x',df['Display'].str.split().str.get(2).str.strip())

# %%
df.head(2)
# Out:
#       Brand                     Name    Price  5G  NFC  IrBlaster  \
# 0   OnePlus     OnePlus Nord CE 4 5G  24999.0   1    0          0
# 1  Motorola  Motorola Edge 50 Pro 5G  31999.0   1    1          0
#
#   Processor_brand Processor_gen Processor_speed Ram  ...  BattryMAH  \
# 0      Snapdragon        7 Gen3            2.63   8  ...       5500
# 1      Snapdragon        7 Gen3            2.63   8  ...       4500
#
#    FastCharging  DisplayHW resulution_x  \
# 0             1        6.7         1080
# 1             1        6.7         1220
#
#                                              Display  \
# 0  6.7 inches, 1080 x 2412 px, 120 Hz Display wit...
# 1  6.7 inches, 1220 x 2712 px, 144 Hz Display wit...
#
#                                               Camera  \
# 0        50 MP + 8 MP Dual Rear & 16 MP Front Camera
# 1  50 MP + 13 MP + 10 MP Triple Rear & 50 MP Fron...
#
#                             Memory   OSType OS_Version  \
# ...

# %%
df['Display'].str.split().str.get(4).str.strip()
# Out:
# 0      2412
# 1      2712
# 2      2772
# 3      2400
# 4      2400
#        ...
# 975    2340
# 976    1520
# 977    2520
# 978    2400
# 979    3088
# Name: Display, Length: 980, dtype: object

# %%
df.insert(17,'resulution_y',df['Display'].str.split().str.get(4).str.strip())

# %%
df.head(2)
# Out:
#       Brand                     Name    Price  5G  NFC  IrBlaster  \
# 0   OnePlus     OnePlus Nord CE 4 5G  24999.0   1    0          0
# 1  Motorola  Motorola Edge 50 Pro 5G  31999.0   1    1          0
#
#   Processor_brand Processor_gen Processor_speed Ram  ...  FastCharging  \
# 0      Snapdragon        7 Gen3            2.63   8  ...             1
# 1      Snapdragon        7 Gen3            2.63   8  ...             1
#
#    DisplayHW  resulution_x resulution_y  \
# 0        6.7          1080         2412
# 1        6.7          1220         2712
#
#                                              Display  \
# 0  6.7 inches, 1080 x 2412 px, 120 Hz Display wit...
# 1  6.7 inches, 1220 x 2712 px, 144 Hz Display wit...
#
#                                               Camera  \
# 0        50 MP + 8 MP Dual Rear & 16 MP Front Camera
# 1  50 MP + 13 MP + 10 MP Triple Rear & 50 MP Fron...
#
#                             Memory   OSType OS_Version  \
# ...

# %%
df['Display'].value_counts()
# Out:
# Display
# 6.67 inches, 1080 x 2400 px, 120 Hz Display with Punch Hole    78
# 6.7 inches, 1080 x 2412 px, 120 Hz Display with Punch Hole     47
# 6.78 inches, 1080 x 2400 px, 120 Hz Display with Punch Hole    26
# 6.78 inches, 1260 x 2800 px, 120 Hz Display with Punch Hole    19
# 6.43 inches, 1080 x 2400 px, 90 Hz Display with Punch Hole     19
#                                                                ..
# 6.81 inches, 1440 x 3200 px, 120 Hz Display with Punch Hole     1
# 5 inches, 1080 x 2400 px, 120 Hz Display with Punch Hole        1
# 6.8 inches, 1080 x 2412 px, 90 Hz Display with Punch Hole       1
# 8.2 inches, 1914 x 2160 px, 144 Hz Display                      1
# 6.9 inches, 1440 x 3088 px, 120 Hz Display with Punch Hole      1
# Name: count, Length: 365, dtype: int64

# %%
df.insert(18,'RefreshRate',df['Display'].str.split(',').str.get(2).str.split().str.get(0).str.strip())

# %%
df.head(4)
# Out:
#       Brand                     Name    Price  5G  NFC  IrBlaster  \
# 0   OnePlus     OnePlus Nord CE 4 5G  24999.0   1    0          0
# 1  Motorola  Motorola Edge 50 Pro 5G  31999.0   1    1          0
# 2   OnePlus        OnePlus Nord 4 5G  32999.0   1    1          1
# 3      Vivo               Vivo T3 5G  19999.0   1    0          0
#
#   Processor_brand Processor_gen Processor_speed Ram  ...  DisplayHW  \
# 0      Snapdragon        7 Gen3            2.63   8  ...        6.7
# 1      Snapdragon        7 Gen3            2.63   8  ...        6.7
# 2      Snapdragon       7+ Gen3             2.8   8  ...       6.78
# 3       Dimensity          7200             2.8   8  ...       6.67
#
#    resulution_x  resulution_y RefreshRate  \
# 0          1080          2412         120
# 1          1220          2712         144
# 2          1240          2772         120
# 3          1080          2400         120
#
#                                              Display  \
# ...

# %%
df['Display'].value_counts()
# Out:
# Display
# 6.67 inches, 1080 x 2400 px, 120 Hz Display with Punch Hole    78
# 6.7 inches, 1080 x 2412 px, 120 Hz Display with Punch Hole     47
# 6.78 inches, 1080 x 2400 px, 120 Hz Display with Punch Hole    26
# 6.78 inches, 1260 x 2800 px, 120 Hz Display with Punch Hole    19
# 6.43 inches, 1080 x 2400 px, 90 Hz Display with Punch Hole     19
#                                                                ..
# 6.81 inches, 1440 x 3200 px, 120 Hz Display with Punch Hole     1
# 5 inches, 1080 x 2400 px, 120 Hz Display with Punch Hole        1
# 6.8 inches, 1080 x 2412 px, 90 Hz Display with Punch Hole       1
# 8.2 inches, 1914 x 2160 px, 144 Hz Display                      1
# 6.9 inches, 1440 x 3088 px, 120 Hz Display with Punch Hole      1
# Name: count, Length: 365, dtype: int64

# %%
def isPHole(text):
    if 'Punch Hole' in text:
        return 1
    return 0

# %%
t=df['Display'].apply(isPHole)

# %%
df.insert(20,'PHole',t)

# %%
df.head(2)
# Out:
#       Brand                     Name    Price  5G  NFC  IrBlaster  \
# 0   OnePlus     OnePlus Nord CE 4 5G  24999.0   1    0          0
# 1  Motorola  Motorola Edge 50 Pro 5G  31999.0   1    1          0
#
#   Processor_brand Processor_gen Processor_speed Ram  ...  resulution_x  \
# 0      Snapdragon        7 Gen3            2.63   8  ...          1080
# 1      Snapdragon        7 Gen3            2.63   8  ...          1220
#
#    resulution_y  RefreshRate  \
# 0          2412          120
# 1          2712          144
#
#                                              Display  PHole  \
# 0  6.7 inches, 1080 x 2412 px, 120 Hz Display wit...      1
# 1  6.7 inches, 1220 x 2712 px, 144 Hz Display wit...      1
#
#                                               Camera  \
# 0        50 MP + 8 MP Dual Rear & 16 MP Front Camera
# 1  50 MP + 13 MP + 10 MP Triple Rear & 50 MP Fron...
#
#                             Memory   OSType OS_Version  \
# ...

# %%
df.drop(columns=['Display'],inplace=True)

# %%
df.head(2)
# Out:
#       Brand                     Name    Price  5G  NFC  IrBlaster  \
# 0   OnePlus     OnePlus Nord CE 4 5G  24999.0   1    0          0
# 1  Motorola  Motorola Edge 50 Pro 5G  31999.0   1    1          0
#
#   Processor_brand Processor_gen Processor_speed Ram  ...  DisplayHW  \
# 0      Snapdragon        7 Gen3            2.63   8  ...        6.7
# 1      Snapdragon        7 Gen3            2.63   8  ...        6.7
#
#    resulution_x  resulution_y RefreshRate  PHole  \
# 0          1080          2412         120      1
# 1          1220          2712         144      1
#
#                                               Camera  \
# 0        50 MP + 8 MP Dual Rear & 16 MP Front Camera
# 1  50 MP + 13 MP + 10 MP Triple Rear & 50 MP Fron...
#
#                             Memory   OSType OS_Version  \
# 0  Memory Card (Hybrid), upto 1 TB  Android       14.0
# 1                      Android v14  Android       14.0
#
#                                           Image Link
# ...

# %%
df.Camera.value_counts()
# Out:
# Camera
# 50 MP + 8 MP + 2 MP Triple Rear & 16 MP Front Camera       51
# 64 MP + 8 MP + 2 MP Triple Rear & 16 MP Front Camera       44
# Foldable Display, Dual Display                             41
# 50 MP + 2 MP Dual Rear & 8 MP Front Camera                 38
# 50 MP + 8 MP Dual Rear & 16 MP Front Camera                16
#                                                            ..
# 64 MP + 50 MP + 8 MP Triple Rear & 16 MP Front Camera       1
# 50 MP + 16 MP + 2 MP Triple Rear & 16 MP Front Camera       1
# 48 MP + 8 MP + 5 MP Triple Rear & 20 MP Front Camera        1
# 8 MP Dual Rear & 5 MP Front Camera                          1
# 108 MP + 12 MP + 12 MP Triple Rear & 10 MP Front Camera     1
# Name: count, Length: 299, dtype: int64

# %%
# Rear camera
df.insert(20,"Rear_camera",df['Camera'].str.split().str.get(0).str.strip())

# %%
df.head(2)
# Out:
#       Brand                     Name    Price  5G  NFC  IrBlaster  \
# 0   OnePlus     OnePlus Nord CE 4 5G  24999.0   1    0          0
# 1  Motorola  Motorola Edge 50 Pro 5G  31999.0   1    1          0
#
#   Processor_brand Processor_gen Processor_speed Ram  ...  resulution_x  \
# 0      Snapdragon        7 Gen3            2.63   8  ...          1080
# 1      Snapdragon        7 Gen3            2.63   8  ...          1220
#
#    resulution_y  RefreshRate PHole  Rear_camera  \
# 0          2412          120     1           50
# 1          2712          144     1           50
#
#                                               Camera  \
# 0        50 MP + 8 MP Dual Rear & 16 MP Front Camera
# 1  50 MP + 13 MP + 10 MP Triple Rear & 50 MP Fron...
#
#                             Memory   OSType OS_Version  \
# 0  Memory Card (Hybrid), upto 1 TB  Android       14.0
# 1                      Android v14  Android       14.0
#
#                                           Image Link
# ...

# %%
df.Rear_camera
# Out:
# 0       50
# 1       50
# 2       50
# 3       50
# 4      108
#       ...
# 975     64
# 976     16
# 977     12
# 978     16
# 979    108
# Name: Rear_camera, Length: 980, dtype: object

# %%
df.Rear_camera.value_counts()
# Out:
# Rear_camera
# 50          424
# 64          199
# 108         135
# 48           57
# 200          53
# Foldable     41
# 12           19
# 13           13
# 100           8
# 16            6
# 8             4
# Dual          4
# 180           3
# 50.3          3
# 21            3
# 12.2          2
# 60            2
# Memory        2
# 40            1
# 54            1
# Name: count, dtype: int64

# %%
df.Camera.value_counts()
# Out:
# Camera
# 50 MP + 8 MP + 2 MP Triple Rear & 16 MP Front Camera       51
# 64 MP + 8 MP + 2 MP Triple Rear & 16 MP Front Camera       44
# Foldable Display, Dual Display                             41
# 50 MP + 2 MP Dual Rear & 8 MP Front Camera                 38
# 50 MP + 8 MP Dual Rear & 16 MP Front Camera                16
#                                                            ..
# 64 MP + 50 MP + 8 MP Triple Rear & 16 MP Front Camera       1
# 50 MP + 16 MP + 2 MP Triple Rear & 16 MP Front Camera       1
# 48 MP + 8 MP + 5 MP Triple Rear & 20 MP Front Camera        1
# 8 MP Dual Rear & 5 MP Front Camera                          1
# 108 MP + 12 MP + 12 MP Triple Rear & 10 MP Front Camera     1
# Name: count, Length: 299, dtype: int64

# %%
df.insert(21,'Font_Camera',df.Camera.str.split('&').str.get(1).str.split().str.get(0))

# %%
df.head(2)
# Out:
#       Brand                     Name    Price  5G  NFC  IrBlaster  \
# 0   OnePlus     OnePlus Nord CE 4 5G  24999.0   1    0          0
# 1  Motorola  Motorola Edge 50 Pro 5G  31999.0   1    1          0
#
#   Processor_brand Processor_gen Processor_speed Ram  ...  resulution_y  \
# 0      Snapdragon        7 Gen3            2.63   8  ...          2412
# 1      Snapdragon        7 Gen3            2.63   8  ...          2712
#
#    RefreshRate  PHole Rear_camera  Font_Camera  \
# 0          120      1          50           16
# 1          144      1          50           50
#
#                                               Camera  \
# 0        50 MP + 8 MP Dual Rear & 16 MP Front Camera
# 1  50 MP + 13 MP + 10 MP Triple Rear & 50 MP Fron...
#
#                             Memory   OSType OS_Version  \
# 0  Memory Card (Hybrid), upto 1 TB  Android       14.0
# 1                      Android v14  Android       14.0
#
#                                           Image Link
# ...

# %%
df['Camera'].value_counts()
# Out:
# Camera
# 50 MP + 8 MP + 2 MP Triple Rear & 16 MP Front Camera       51
# 64 MP + 8 MP + 2 MP Triple Rear & 16 MP Front Camera       44
# Foldable Display, Dual Display                             41
# 50 MP + 2 MP Dual Rear & 8 MP Front Camera                 38
# 50 MP + 8 MP Dual Rear & 16 MP Front Camera                16
#                                                            ..
# 64 MP + 50 MP + 8 MP Triple Rear & 16 MP Front Camera       1
# 50 MP + 16 MP + 2 MP Triple Rear & 16 MP Front Camera       1
# 48 MP + 8 MP + 5 MP Triple Rear & 20 MP Front Camera        1
# 8 MP Dual Rear & 5 MP Front Camera                          1
# 108 MP + 12 MP + 12 MP Triple Rear & 10 MP Front Camera     1
# Name: count, Length: 299, dtype: int64

# %%
def isTriplCamera(text):
    if 'Triple' or 'Quad' in text:
        return 1
    return 0

# %%
df.drop(columns=['Camera'],inplace=True)

# %%
df.head(4)
# Out:
#       Brand                     Name    Price  5G  NFC  IrBlaster  \
# 0   OnePlus     OnePlus Nord CE 4 5G  24999.0   1    0          0
# 1  Motorola  Motorola Edge 50 Pro 5G  31999.0   1    1          0
# 2   OnePlus        OnePlus Nord 4 5G  32999.0   1    1          1
# 3      Vivo               Vivo T3 5G  19999.0   1    0          0
#
#   Processor_brand Processor_gen Processor_speed Ram  ...  resulution_x  \
# 0      Snapdragon        7 Gen3            2.63   8  ...          1080
# 1      Snapdragon        7 Gen3            2.63   8  ...          1220
# 2      Snapdragon       7+ Gen3             2.8   8  ...          1240
# 3       Dimensity          7200             2.8   8  ...          1080
#
#    resulution_y  RefreshRate PHole  Rear_camera Font_Camera  \
# 0          2412          120     1           50          16
# 1          2712          144     1           50          50
# 2          2772          120     1           50          32
# ...

# %%
def camera(text):
    if 'Camera' in text:
        return 1
    return 0

# %%
temp=df['Memory'].apply(camera)

# %%
df.insert(21,"test",temp)

# %%
t=df[df['test']==1]

# %%
rear1=t['Memory'].str.split().str.get(0).str.strip()

# %%
t['Memory'].str.split().str.get(0).str.strip()
# Out:
# 124     50
# 182     50
# 207     50
# 294     64
# 342     50
# 349     64
# 393     50
# 397     64
# 422     12
# 447     13
# 468     50
# 474     50
# 482     12
# 522    200
# 523    108
# 527     12
# 533     50
# 535     50
# 574     64
# 638     50
# 642     50
# 681     64
# 687     50
# 701     50
# 709     50
# 747     50
# 753    108
# 754     50
# 759     64
# 770     50
# 777     50
# 778     50
# 800     50
# 804    108
# 822     50
# 867     12
# 890     50
# 894     50
# 897    200
# 898     64
# 914     50
# 917     50
# 919     48
# 928     50
# 972     12
# Name: Memory, dtype: object

# %%
df.loc[df['test']==1,'Rear_camera']=t['Memory'].str.split().str.get(0).str.strip()

# %%
t['Memory'].str.split('&').str.get(1).str.split().str.get(0)
# Out:
# 124     32
# 182     12
# 207     32
# 294     32
# 342     32
# 349     32
# 393     10
# 397     32
# 422     10
# 447     32
# 468     12
# 474     32
# 482     10
# 522     50
# 523     32
# 527     10
# 533     16
# 535     20
# 574     32
# 638     16
# 642     32
# 681     16
# 687     12
# 701     32
# 709     32
# 747     10
# 753     32
# 754     32
# 759     32
# 770     16
# 777     16
# 778     10
# 800     16
# 804     32
# 822     32
# 867     10
# 890      8
# 894     10
# 897     32
# 898     32
# 914     32
# 917     32
# 919    9.5
# 928     10
# 972     10
# Name: Memory, dtype: object

# %%
df.loc[df['test']==1,'Font_Camera']=t['Memory'].str.split('&').str.get(1).str.split().str.get(0)

# %%
df.loc[df['test']==1,'Price']
# Out:
# 124     80990.0
# 182    179990.0
# 207     80990.0
# 294    133100.0
# 342     89990.0
# 349     43450.0
# 393    154999.0
# 397    115990.0
# 422     59990.0
# 447     64999.0
# 468    199990.0
# 474     69799.0
# 482     45999.0
# 522    119990.0
# 523    119900.0
# 527     91899.0
# 533    106990.0
# 535    106990.0
# 574    109900.0
# 638    187990.0
# 642     89990.0
# 681    134999.0
# 687    159990.0
# 701     94999.0
# 709     69990.0
# 747    184999.0
# 753     99990.0
# 754     89999.0
# 759    114990.0
# 770    102999.0
# 777     94990.0
# 778    134999.0
# 800     54900.0
# 804     32990.0
# 822     89990.0
# 867     40999.0
# 890     67990.0
# 894    149999.0
# 897    139990.0
# 898     59990.0
# 914     79990.0
# 917     71990.0
# 919    146990.0
# 928    119000.0
# 972     89999.0
# Name: Price, dtype: float64

# %%
df.head()
# Out:
#       Brand                       Name    Price  5G  NFC  IrBlaster  \
# 0   OnePlus       OnePlus Nord CE 4 5G  24999.0   1    0          0
# 1  Motorola    Motorola Edge 50 Pro 5G  31999.0   1    1          0
# 2   OnePlus          OnePlus Nord 4 5G  32999.0   1    1          1
# 3      Vivo                 Vivo T3 5G  19999.0   1    0          0
# 4   OnePlus  OnePlus Nord CE 4 Lite 5G  20990.0   1    0          0
#
#   Processor_brand Processor_gen Processor_speed Ram  ...  resulution_y  \
# 0      Snapdragon        7 Gen3            2.63   8  ...          2412
# 1      Snapdragon        7 Gen3            2.63   8  ...          2712
# 2      Snapdragon       7+ Gen3             2.8   8  ...          2772
# 3       Dimensity          7200             2.8   8  ...          2400
# 4      Snapdragon        7 Gen1             2.4   8  ...          2400
#
#    RefreshRate  PHole Rear_camera  test Font_Camera  \
# 0          120      1          50     0          16
# ...

# %%
df.insert(23,'Expandable',df['Memory'].str.split('upto').str.get(-1).str.split().str.get(0).str.strip())

# %%
df.Memory.sample()
# Out:
# 533    50 MP Quad Rear & 16 MP Front Camera
# Name: Memory, dtype: object

# %%
# df['Expandable']=df['Expandable'].apply(count)

# %%
df['Expandable'].value_counts()
# Out:
# Expandable
# Android      313
# 1            289
# Memory       224
# 2             39
# 512           31
# 256           27
# 50            26
# 64             7
# 12             5
# 108            3
# Flyme          3
# 200            2
# iOS            2
# 128            2
# HarmonyOS      2
# EMUI           2
# 13             1
# 1000           1
# 48             1
# Name: count, dtype: int64

# %%
df.loc[df['Expandable']=='HarmonyOS','Expandable']=1024

# %%
df.loc[df['Expandable']=='Flyme','Expandable']=1024

# %%
df.Brand.value_counts()
# Out:
# Brand
# Samsung       133
# Vivo          118
# Xiaomi        101
# Realme         85
# OnePlus        55
# Motorola       54
# OPPO           47
# Poco           42
# Infinix        38
# Tecno          37
# iQOO           34
# Honor          31
# Apple          29
# Oppo           25
# Nubia          20
# Google         15
# Huawei         14
# Lava           14
# Nothing        13
# Sony           12
# Asus           11
# Nokia          11
# POCO            6
# Meizu           6
# itel            5
# Ulefone         3
# iKall           3
# Oukitel         3
# ZTE             2
# Gionee          2
# Energizer       2
# Solana          1
# Black           1
# Blackberry      1
# Tesla           1
# Unihertz        1
# Doogee          1
# Blackview       1
# Duoqin          1
# Redmi           1
# Name: count, dtype: int64

# %%
df.loc[df['Brand']=='Apple','Expandable']=0

# %%
df.loc[df['Expandable']=='Memory','Expandable']=0

# %%
def te(text):
    if text<10000:
        return 512
    elif text<50000:
        return 1024
    return 2*1024

# %%
temp=df.loc[df['Expandable']=='Android','Price'].apply(te)

# %%
df.loc[df['Expandable']=='Android','Expandable']=temp

# %%
df.Expandable.value_counts()
# Out:
# Expandable
# 1       289
# 1024    234
# 0       226
# 2048     82
# 2        39
# 512      31
# 256      27
# 50       26
# 64        7
# 12        5
# 108       3
# 128       2
# 200       2
# 512       2
# EMUI      2
# 13        1
# 1000      1
# 48        1
# Name: count, dtype: int64

# %%
def count(text):
    if 0==text:
        return 0
    if '256' == text:
        return 256
    elif '512' == text:
        return 512
    elif '1' == text:
        return 1024
    elif '2' == text:
        return 2*1024
    return 1024

# %%
# df['Expandable']=df['Expandable'].astype('object')

# %%
df['Expandable']=df['Expandable'].apply(count)

# %%
df.Expandable.value_counts()
# Out:
# Expandable
# 1024    657
# 0       226
# 2048     39
# 512      31
# 256      27
# Name: count, dtype: int64

# %%
df.drop(columns=['Memory','test'],inplace=True)

# %%
df.head()
# Out:
#       Brand                       Name    Price  5G  NFC  IrBlaster  \
# 0   OnePlus       OnePlus Nord CE 4 5G  24999.0   1    0          0
# 1  Motorola    Motorola Edge 50 Pro 5G  31999.0   1    1          0
# 2   OnePlus          OnePlus Nord 4 5G  32999.0   1    1          1
# 3      Vivo                 Vivo T3 5G  19999.0   1    0          0
# 4   OnePlus  OnePlus Nord CE 4 Lite 5G  20990.0   1    0          0
#
#   Processor_brand Processor_gen Processor_speed Ram  ...  resulution_x  \
# 0      Snapdragon        7 Gen3            2.63   8  ...          1080
# 1      Snapdragon        7 Gen3            2.63   8  ...          1220
# 2      Snapdragon       7+ Gen3             2.8   8  ...          1240
# 3       Dimensity          7200             2.8   8  ...          1080
# 4      Snapdragon        7 Gen1             2.4   8  ...          1080
#
#    resulution_y  RefreshRate PHole  Rear_camera Font_Camera Expandable  \
# ...

# %%
df.shape
# Out:
# (980, 26)

# %%
df.drop_duplicates(inplace=True)

# %%
df.duplicated().sum()
# Out:
# 0

# %%
def isfold(text):
    if 'Fold' in text:
        return 1
    return 0

# %%
df.insert(3,"Foldable",df['Name'].apply(isfold))

# %%
df.shape
# Out:
# (967, 27)

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# Index: 967 entries, 0 to 979
# Data columns (total 27 columns):
#  #   Column           Non-Null Count  Dtype
# ---  ------           --------------  -----
#  0   Brand            967 non-null    object
#  1   Name             967 non-null    object
#  2   Price            967 non-null    float64
#  3   Foldable         967 non-null    int64
#  4   5G               967 non-null    int64
#  5   NFC              967 non-null    int64
#  6   IrBlaster        967 non-null    int64
#  7   Processor_brand  967 non-null    object
#  8   Processor_gen    960 non-null    object
#  9   Processor_speed  965 non-null    object
#  10  Ram              967 non-null    object
#  11  Cores            967 non-null    int64
#  12  Rating           967 non-null    float64
#  13  Storage          967 non-null    Int64
#  14  BattryMAH        967 non-null    object
#  15  FastCharging     967 non-null    int64
#  16  DisplayHW        967 non-null    object
# ...

# %%
df.to_csv('./Datasets/Clined_Smart_01.csv',index=False)

# %%
df=pd.read_csv('./Datasets/Clined_Smart_01.csv')

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 967 entries, 0 to 966
# Data columns (total 27 columns):
#  #   Column           Non-Null Count  Dtype
# ---  ------           --------------  -----
#  0   Brand            967 non-null    object
#  1   Name             967 non-null    object
#  2   Price            967 non-null    float64
#  3   Foldable         967 non-null    int64
#  4   5G               967 non-null    int64
#  5   NFC              967 non-null    int64
#  6   IrBlaster        967 non-null    int64
#  7   Processor_brand  967 non-null    object
#  8   Processor_gen    960 non-null    object
#  9   Processor_speed  965 non-null    object
#  10  Ram              967 non-null    int64
#  11  Cores            967 non-null    int64
#  12  Rating           967 non-null    float64
#  13  Storage          967 non-null    int64
#  14  BattryMAH        967 non-null    object
#  15  FastCharging     967 non-null    int64
#  16  DisplayHW        967 non-null    float64
# ...
